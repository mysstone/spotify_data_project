# %%
import pandas as pd
import pprint
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 150)

# %%
stream_final_df = pd.read_csv('data/spotify_streaming_cleaned.csv')

# %%
stream_final_df.groupby('mountain_hour').agg({
    'ms_played': 'sum', 
    'ts': 'count',
    'master_metadata_album_artist_name': 'first'
}).sort_values(by='ms_played', ascending=False)
# Out:
#                ms_played    ts master_metadata_album_artist_name
# mountain_hour
# 14             714122377  7591                     Frank Sinatra
# 15             671211453  7890                     Hudson Thames
# 17             643587067  8721                             Birdy
# 16             613690078  7530                   Victorious Cast
# 13             587875991  6124                        Dame Dolla
# 18             545862600  7639                        Cher Lloyd
# 12             492109627  4968                     Hudson Thames
# 19             448448725  6718                       Saint Motel
# 21             446635059  7339                   Nikolai Medtner
# 20             426287584  6023                     Hudson Thames
# 11             402260705  4074                       Circa Waves
# 22             348386648  8066                           Shakira
# 23             284971767  7378                    Kendrick Lamar
# 10             269290937  3479                      Selena Gomez
# 0              216506082  5039                             Drake
# 9              144300906  1751                    Secret Weapons
# 1              126920100  3263                       Circa Waves
# 7               90323316  1413                 Tokyo Police Club
# 8               83680120   943                            POWERS
# 4               77662767   981                Hildur Guðnadóttir
# 2               73929257  2311                        Red Velvet
# 5               62437564   653                              YVES
# 3               60766512  1017                        Red Velvet
# 6               48649390   629                    Last Dinosaurs

# %%
len(stream_final_df["spotify_track_uri"].unique())
# Out:
# 30706

# %%
track_uri_df = stream_final_df.groupby('spotify_track_uri').agg({
    'master_metadata_track_name' : 'first',
    'master_metadata_album_artist_name' : 'first'
})

# %%
track_uri_df.reset_index()

track_uri_df.to_csv("data/unique_songs.csv")

# %%
stream_final_df.loc[stream_final_df["ms_played"] < 30000]
# Out:
#         Unnamed: 0                    ts  ms_played conn_country  \
# 0                0  2016-01-08T16:57:23Z      14257           US
# 2                2  2016-01-08T17:01:09Z        994           US
# 3                3  2016-01-08T17:01:11Z       2461           US
# 4                4  2016-01-08T17:01:12Z       1044           US
# 6                6  2016-01-08T17:03:31Z       1834           US
# ...            ...                   ...        ...          ...
# 111517      111626  2025-03-10T17:19:20Z       1834           US
# 111521      111630  2025-03-10T17:27:08Z       7337           US
# 111522      111631  2025-03-10T17:27:10Z       2530           US
# 111523      111632  2025-03-10T17:27:11Z        371           US
# 111537      111646  2025-03-11T17:45:16Z      12933           US
#
#                             master_metadata_track_name  \
# 0                                        Something New
# 2                                            Survivors
# 3                                           Without Me
# 4                                                Magic
# 6                                                Traum
# ...                                                ...
# 111517                                     Gangsta Kid
# 111521                                Jungle Buddy Bye
# 111522                                      It's Jazzy
# 111523  Under Mi Sensi (Jungle Spliff) X Project Remix
# 111537                 The Angels Fell - 2015 Remaster
#
#        master_metadata_album_artist_name  \
# 0                         Secret Weapons
# 2                           Selena Gomez
# 3                                 Eminem
# 4                              San Cisco
# 6                                    CRO
# ...                                  ...
# 111517                            SHY FX
# 111521                   Johnny Osbourne
# 111522                         Roni Size
# 111523                   Barrington Levy
# 111537                          Dillinja
#
#                          master_metadata_album_album_name  \
# 0                                           Something New
# 2                                                 Revival
# 3                                         The Eminem Show
# 4                                               Gracetown
# 6                                                   Traum
# ...                                                   ...
# 111517                                Jungle Hits, Vol. 1
# 111521                      Ragga Jungle Anthems Vol. Two
# 111522                                          V Classic
# 111523                      Ragga Jungle Anthems Vol. One
# 111537  The Angels Fell / Ja Know Ya Big / Brutal Bass...
#
#                            spotify_track_uri reason_start reason_end  shuffle  \
# 0       spotify:track:3Tg7AXyFD0frtV3CAVjyZ3       fwdbtn    endplay     True
# 2       spotify:track:6mEFvpqnzElavdz3gfP2XT    trackdone    endplay     True
# 3       spotify:track:7lQ8MOhq6IN2w8EYcFNSUk     clickrow     fwdbtn     True
# 4       spotify:track:2madhIZgRsvGBGyjSOnlMl       fwdbtn     fwdbtn     True
# 6       spotify:track:7jIRQUJbgJSakbO87fZihr       fwdbtn     fwdbtn     True
# ...                                      ...          ...        ...      ...
# 111517  spotify:track:6bFSjdbVlm4FQeqUO6hwGe      playbtn     fwdbtn    False
# 111521  spotify:track:6Hz7YEzHb3FrXpqadKYb3E       fwdbtn     fwdbtn     True
# 111522  spotify:track:7wVqeFQqdQ8V6wNjbFKYIv       fwdbtn     fwdbtn     True
# 111523  spotify:track:0rFGpzZJM4gveQPlusXtGX       fwdbtn    backbtn     True
# 111537  spotify:track:4PVzD2FbJuMi5TgKNEVURw       fwdbtn    endplay     True
#
#         skipped                  timestamp              mountain_time  \
# 0          True  2016-01-08 16:57:23+00:00  2016-01-08 09:57:23-07:00
# 2          True  2016-01-08 17:01:09+00:00  2016-01-08 10:01:09-07:00
# 3          True  2016-01-08 17:01:11+00:00  2016-01-08 10:01:11-07:00
# 4          True  2016-01-08 17:01:12+00:00  2016-01-08 10:01:12-07:00
# 6          True  2016-01-08 17:03:31+00:00  2016-01-08 10:03:31-07:00
# ...         ...                        ...                        ...
# 111517     True  2025-03-10 17:19:20+00:00  2025-03-10 11:19:20-06:00
# 111521     True  2025-03-10 17:27:08+00:00  2025-03-10 11:27:08-06:00
# 111522     True  2025-03-10 17:27:10+00:00  2025-03-10 11:27:10-06:00
# 111523     True  2025-03-10 17:27:11+00:00  2025-03-10 11:27:11-06:00
# 111537     True  2025-03-11 17:45:16+00:00  2025-03-11 11:45:16-06:00
#
#         mountain_hour  year  month
# 0                   9  2016      1
# 2                  10  2016      1
# 3                  10  2016      1
# 4                  10  2016      1
# 6                  10  2016      1
# ...               ...   ...    ...
# 111517             11  2025      3
# 111521             11  2025      3
# 111522             11  2025      3
# 111523             11  2025      3
# 111537             11  2025      3
#
# [61073 rows x 17 columns]

# %%
stream_final_df.dtypes
# Out:
# Unnamed: 0                            int64
# ts                                   object
# ms_played                             int64
# conn_country                         object
# master_metadata_track_name           object
# master_metadata_album_artist_name    object
# master_metadata_album_album_name     object
# spotify_track_uri                    object
# reason_start                         object
# reason_end                           object
# shuffle                                bool
# skipped                                bool
# timestamp                            object
# mountain_time                        object
# mountain_hour                         int64
# year                                  int64
# month                                 int64
# dtype: object

# %%
# Convert mountain_time from object to datetime
stream_final_df['mountain_time'] = pd.to_datetime(stream_final_df['mountain_time'], errors='coerce')

# Check if any values couldn't be converted (will be NaT)
missing_dates = stream_final_df['mountain_time'].isna().sum()
print(f"Number of rows with invalid dates: {missing_dates}")

# If there are invalid dates, you might want to examine them
if missing_dates > 0:
    invalid_dates = stream_final_df.loc[stream_final_df['mountain_time'].isna(), 'mountain_time']
    print("Sample of invalid date strings:")
    print(invalid_dates.head())

# Once converted, create the day of week columns
stream_final_df['day_of_week'] = stream_final_df['mountain_time'].dt.dayofweek

day_map = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}
stream_final_df['day_name'] = stream_final_df['day_of_week'].map(day_map)
# Out:
# Number of rows with invalid dates: 73370
# Sample of invalid date strings:
# 792   NaT
# 793   NaT
# 794   NaT
# 795   NaT
# 796   NaT
# Name: mountain_time, dtype: datetime64[ns, UTC-07:00]

# %%
stream_final_df
# Out:
#         Unnamed: 0                    ts  ms_played conn_country  \
# 0                0  2016-01-08T16:57:23Z      14257           US
# 1                1  2016-01-08T17:01:07Z     229080           US
# 2                2  2016-01-08T17:01:09Z        994           US
# 3                3  2016-01-08T17:01:11Z       2461           US
# 4                4  2016-01-08T17:01:12Z       1044           US
# ...            ...                   ...        ...          ...
# 111535      111644  2025-03-11T17:40:18Z     247640           US
# 111536      111645  2025-03-11T17:45:03Z     283211           US
# 111537      111646  2025-03-11T17:45:16Z      12933           US
# 111538      111647  2025-03-11T17:52:33Z     437152           US
# 111539      111648  2025-03-11T19:21:07Z     349087           US
#
#              master_metadata_track_name master_metadata_album_artist_name  \
# 0                         Something New                    Secret Weapons
# 1                         Same Old Love                      Selena Gomez
# 2                             Survivors                      Selena Gomez
# 3                            Without Me                            Eminem
# 4                                 Magic                         San Cisco
# ...                                 ...                               ...
# 111535                       The Burial                         Leviticus
# 111536  Here I Come (feat. Mega Banton)                   Barrington Levy
# 111537  The Angels Fell - 2015 Remaster                          Dillinja
# 111538                          So Long                              Seba
# 111539                   Tychonic Cycle                           Jonny L
#
#                          master_metadata_album_album_name  \
# 0                                           Something New
# 1                                                 Revival
# 2                                                 Revival
# 3                                         The Eminem Show
# 4                                               Gracetown
# ...                                                   ...
# 111535                                Jungle Hits, Vol. 1
# 111536                      Ragga Jungle Anthems Vol. Two
# 111537  The Angels Fell / Ja Know Ya Big / Brutal Bass...
# 111538                                        Producer 06
# 111539                                           Sawtooth
#
#                            spotify_track_uri reason_start  \
# 0       spotify:track:3Tg7AXyFD0frtV3CAVjyZ3       fwdbtn
# 1       spotify:track:1BZG99C7Co1r6QUC3zaS59     clickrow
# 2       spotify:track:6mEFvpqnzElavdz3gfP2XT    trackdone
# 3       spotify:track:7lQ8MOhq6IN2w8EYcFNSUk     clickrow
# 4       spotify:track:2madhIZgRsvGBGyjSOnlMl       fwdbtn
# ...                                      ...          ...
# 111535  spotify:track:0BIAlQguOM4MSEDUjqOqkc    trackdone
# 111536  spotify:track:2kIZcL8XslmgWISM8zxa93    trackdone
# 111537  spotify:track:4PVzD2FbJuMi5TgKNEVURw       fwdbtn
# 111538  spotify:track:6ChYON7kJVT2RNtKmQZaJL      playbtn
# 111539  spotify:track:5NSbvAshLlhDvSlokHbJZ9    trackdone
#
#                           reason_end  shuffle  skipped  \
# 0                            endplay     True     True
# 1                          trackdone     True    False
# 2                            endplay     True     True
# 3                             fwdbtn     True     True
# 4                             fwdbtn     True     True
# ...                              ...      ...      ...
# 111535                     trackdone     True    False
# 111536                        fwdbtn     True     True
# 111537                       endplay     True     True
# 111538                     trackdone    False    False
# 111539  unexpected-exit-while-paused    False    False
#
#                         timestamp             mountain_time  mountain_hour  \
# 0       2016-01-08 16:57:23+00:00 2016-01-08 09:57:23-07:00              9
# 1       2016-01-08 17:01:07+00:00 2016-01-08 10:01:07-07:00             10
# 2       2016-01-08 17:01:09+00:00 2016-01-08 10:01:09-07:00             10
# 3       2016-01-08 17:01:11+00:00 2016-01-08 10:01:11-07:00             10
# 4       2016-01-08 17:01:12+00:00 2016-01-08 10:01:12-07:00             10
# ...                           ...                       ...            ...
# 111535  2025-03-11 17:40:18+00:00                       NaT             11
# 111536  2025-03-11 17:45:03+00:00                       NaT             11
# 111537  2025-03-11 17:45:16+00:00                       NaT             11
# 111538  2025-03-11 17:52:33+00:00                       NaT             11
# 111539  2025-03-11 19:21:07+00:00                       NaT             13
#
#         year  month  day_of_week day_name
# 0       2016      1          4.0   Friday
# 1       2016      1          4.0   Friday
# 2       2016      1          4.0   Friday
# 3       2016      1          4.0   Friday
# 4       2016      1          4.0   Friday
# ...      ...    ...          ...      ...
# 111535  2025      3          NaN      NaN
# 111536  2025      3          NaN      NaN
# 111537  2025      3          NaN      NaN
# 111538  2025      3          NaN      NaN
# 111539  2025      3          NaN      NaN
#
# [111540 rows x 19 columns]

# %%
# Group by day of week and hour, count plays
heatmap_data = stream_final_df.groupby(['day_name', 'mountain_hour']).size().reset_index(name='play_count')

# Pivot the data to create a matrix
pivot_data = heatmap_data.pivot(index='day_name', columns='mountain_hour', values='play_count')

# Reorder the days (optional, to get Monday at the top or Sunday at the top)
# For Monday at top:
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
pivot_data = pivot_data.reindex(day_order)

# Create the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 8))
sns.heatmap(pivot_data, cmap='Blues', annot=True, fmt='g')
plt.title('Spotify Listening Patterns by Day of Week and Hour')
plt.yticks(rotation=45)
plt.yticks(rotation=45, ha='right')
plt.xlabel('Hour of Day')
plt.ylabel('Day of Week')
plt.show()

# %%
reasons_df = stream_final_df.groupby(["reason_end"]).agg({
    'ts': 'count'
    
    }
).reset_index().sort_values(by="ts")

# %%
reasons_df

# %%
stream_final_df["reason_start"].unique()

# %%
streamed_year_df.to_csv("tracks_by_time_and_streams.csv")

# %%
streamed_year_df.sort_values(by='ms_played', ascending=False)

# %%
import plotly.express as px

streamed_df_sorted = streamed_year_df.sort_values(by='ms_played', ascending=False)

def truncate_text(text, max_length=20):
    if isinstance(text, str) and len(text) > max_length:
        return text[:max_length] + '...'
    return text

# Apply truncation to track names
streamed_df_sorted['truncated_track_names'] = streamed_df_sorted['master_metadata_track_name'].apply(
    lambda x: truncate_text(x, max_length=20)
)

streamed_df_sorted['hours_played'] = streamed_df_sorted['ms_played'] / (1000 * 60 * 60)
streamed_df_sorted['avg_time_per_play'] = (streamed_df_sorted['ms_played'] / streamed_df_sorted['ts']) / (1000 * 60)

streamed_df_sorted.head(20)
new_fig = px.bar(
    streamed_df_sorted.head(20), 
    x='truncated_track_names', 
    y='hours_played',
    custom_data=['master_metadata_track_name', 'master_metadata_album_artist_name', 'hours_played', 'avg_time_per_play']
)
new_fig.update_traces(
    hovertemplate='<b>%{customdata[0]}</b><br>' +
                  'Artist: %{customdata[1]}<br>' +
                  'Total play time: %{y:.2f} hours<br>' +  
                  'Avg time per play: %{customdata[3]:.2f} minutes<extra></extra>'
)

new_fig.update_layout(
    yaxis_title="Hours played",
    xaxis=dict(
        title="Track Name",
        tickangle=45,
        tickfont=dict(size=10)
    ),
    margin=dict(b=100)
)


new_fig.show()

# %%
stream_final_df.groupby(["master_metadata_track_name"])[["ms_played"]].sum().sort_values(by="ms_played", ascending=False)

# %%
streamed_final_gb_df = streamed_final_df.groupby(['master_metadata_track_name', 'master_metadata_album_artist_name']).agg({   
    'ms_played': 'sum', 
    'ts': 'count',
    #'master_metadata_track_name': 'count'
})

streamed_final_gb_df = streamed_final_gb_df.reset_index()

# %%
streamed_final_gb_df = streamed_final_gb_df.sort_values(by="ms_played", ascending=False)

streamed_final_gb_df

# %% [markdown]
# # Questions
#
# ### 1. What consitutes a "play"? Use Machine learning to determine a good range.
# ### 2. What times do listen to the most, and based on that information, when am I most likely to listen?
# ### 3. What are my clustering listening habits? What kinds of music do I like listening to, and when?
# ### 4. Using Spotify API data, what kinds of music would I like moving forward?
# ### 5. What effect does skipping have on my viewing habits? Or just any action?
